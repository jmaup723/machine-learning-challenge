# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#list(df.columns) 
df.dtypes
# Out:
# koi_disposition       object
# koi_fpflag_nt          int64
# koi_fpflag_ss          int64
# koi_fpflag_co          int64
# koi_fpflag_ec          int64
# koi_period           float64
# koi_period_err1      float64
# koi_period_err2      float64
# koi_time0bk          float64
# koi_time0bk_err1     float64
# koi_time0bk_err2     float64
# koi_impact           float64
# koi_impact_err1      float64
# koi_impact_err2      float64
# koi_duration         float64
# koi_duration_err1    float64
# koi_duration_err2    float64
# koi_depth            float64
# koi_depth_err1       float64
# koi_depth_err2       float64
# koi_prad             float64
# koi_prad_err1        float64
# koi_prad_err2        float64
# koi_teq                int64
# koi_insol            float64
# koi_insol_err1       float64
# koi_insol_err2       float64
# koi_model_snr        float64
# koi_tce_plnt_num       int64
# koi_steff              int64
# koi_steff_err1         int64
# koi_steff_err2         int64
# ...

# %%
X = df.drop("koi_disposition", axis=1)

# %%
y = df["koi_disposition"]

# %%
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4002              0              0              1              0   99.673478
# 4246              0              1              0              0    0.592244
# 548               0              1              1              0    9.991625
# 3953              0              1              0              0  178.412990
# 2362              0              0              0              0   45.294223
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4002     3.463000e-04    -3.463000e-04   219.334830          0.002300
# 4246     9.000000e-08    -9.000000e-08   131.654831          0.000124
# 548      5.360000e-06    -5.360000e-06   137.447816          0.000445
# 3953     3.100000e-05    -3.100000e-05   218.225235          0.000127
# 2362     5.600000e-05    -5.600000e-05   138.678725          0.000987
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)
# Out:
# C:\Users\johna\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
clf = clf.fit(X_train_minmax, y_train)

# %%
print(f"Training Data Score: {clf.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {clf.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8489702517162472

# %%
from sklearn.model_selection import GridSearchCV
dt_model = tree.DecisionTreeClassifier()

# %%
dt_param_grid = {'max_depth':[3,9,11,15], 'min_samples_leaf':[5,10,35,60,180]}

# %%
dt_grid = GridSearchCV(dt_model, dt_param_grid, verbose=3)
dt_grid.fit(X_train_minmax, y_train)
print("fin")
# Out:
# C:\Users\johna\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] max_depth=3, min_samples_leaf=5 .................................
# [CV]  max_depth=3, min_samples_leaf=5, score=0.7425629290617849, total=   0.0s
# [CV] max_depth=3, min_samples_leaf=5 .................................
# [CV]  max_depth=3, min_samples_leaf=5, score=0.738558352402746, total=   0.0s
# [CV] max_depth=3, min_samples_leaf=5 .................................
# ...

# %%
dt_predictions= dt_grid.predict(X_test_minmax)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, dt_predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.66      0.74       422
#      CONFIRMED       0.73      0.87      0.79       450
# FALSE POSITIVE       0.98      0.99      0.99       876
#
#      micro avg       0.88      0.88      0.88      1748
#      macro avg       0.85      0.84      0.84      1748
#   weighted avg       0.88      0.88      0.88      1748

# %%
print(dt_grid.best_params_)
print(dt_grid.best_score_)
# Out:
# {'max_depth': 9, 'min_samples_leaf': 10}
# 0.8855617013160404
